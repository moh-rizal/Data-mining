# %%
import pandas as pd
pd.read_csv("data.csv",sep="|")
# Out:
#     usia  tinggi  ukuranSepatu  angkaFavorit
# 0     22     167            36             7
# 1     21     175            36             6
# 2     17     177            35            90
# 3     20     167            38            83
# 4     17     180            34            34
# 5     19     173            32            66
# 6     21     172            37            71
# 7     17     174            34            93
# 8     17     185            30            75
# 9     17     177            39            26
# 10    19     173            30            46
# 11    18     182            35             8
# 12    23     179            39            85
# 13    24     169            35             2
# 14    21     166            39            50
# 15    17     176            31            55
# 16    22     178            39            51
# 17    18     178            37            64
# 18    22     170            40            82
# 19    24     171            34            30
# ...

# %%
from scipy import stats
d1=pd.read_csv("data.csv",sep="|",usecols=['usia','tinggi','ukuranSepatu','angkaFavorit'])
d1.describe()
# Out:
#              usia      tinggi  ukuranSepatu  angkaFavorit
# count  100.000000  100.000000    100.000000    100.000000
# mean    20.330000  174.270000     35.380000     51.150000
# std      2.361539    5.622565      3.148769     29.539009
# min     17.000000  165.000000     30.000000      2.000000
# 25%     18.000000  170.000000     32.750000     26.750000
# 50%     20.000000  174.000000     36.000000     50.000000
# 75%     23.000000  178.000000     38.000000     80.000000
# max     24.000000  185.000000     40.000000    100.000000

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
d2=pd.read_csv("data.csv",sep="|",usecols=["tinggi"])
d3=pd.read_csv("data.csv",sep="|",usecols=["usia"])
d4=pd.read_csv("data.csv",sep="|",usecols=["ukuranSepatu"])
d5=pd.read_csv("data.csv",sep="|",usecols=["angkaFavorit"])
sns.distplot(d2)
sns.distplot(d3)
sns.distplot(d4)
sns.distplot(d5)

# %%
skew=d1["usia"].skew()
print(skew)
# Out:
# 0.04133615912657121
